# %% [markdown]
# # Temporal Stability Quickstart
#
# Este notebook resume o fluxo base do RiskBands: ajuste, pivot temporal, diagnostico por safra e consolidacao auditavel.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "RiskBands").exists():
    ROOT = ROOT.parent

EXAMPLE_DIR = ROOT / "examples" / "temporal_stability"
if str(EXAMPLE_DIR) not in sys.path:
    sys.path.insert(0, str(EXAMPLE_DIR))

from temporal_stability_example import run_temporal_stability_demo

# %%
results = run_temporal_stability_demo()

results["summary"][["variable", "temporal_score", "alert_flags"]]

# %%
results["audit_report"][["variable", "objective_score", "key_penalties", "rationale_summary"]]

# %% [markdown]
# ## Quando avancar para o exemplo de credito
#
# Depois deste quickstart, o proximo passo recomendado e abrir `examples/pd_vintage_champion_challenger/` para ver como as mesmas pecas sustentam uma narrativa mais aderente a PD com multiplas safras.
